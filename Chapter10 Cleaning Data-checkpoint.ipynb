# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data_clean_bfclean.csv')
df
# Out:
#       PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_M
# 0     กอบ   104.0   PUTNAM            Y           3.0        1   1000
# 1     แนน   197.0    LETON            n           3.0        1     --
# 2     Lam     NaN    LETON            N           NaN        1    850
# 3   Ninan   201.0    BEREY            N           1.0       -2  700.5
# 4     Nii     NaN    BEREY            Y           2.0     2ABC   1600
# 5     Tom   207.0    BEREY            Y           3.0      1.5  800.8
# 6   Green     NaN   WAGTON          NaN           2.0        3    950
# 7   Shasa   213.0  TREMONT            Y           1.0        1    NaN
# 8   Alisa   215.0  TREMONT            Y           2.0        2   1800
# 9     Ksb   216.0  TREMONT            n           2.0        2   90.5
# 10    Jib   217.0  TREMONT           12           2.0        2   70.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           11 non-null     object
#  1   ST_NUM        8 non-null      float64
#  2   ST_NAME       11 non-null     object
#  3   OWN_OCCUPIED  10 non-null     object
#  4   NUM_BEDROOMS  10 non-null     float64
#  5   NUM_BATH      11 non-null     object
#  6   SQ_M          10 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes

# %%
df.dtypes
# Out:
# PID              object
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS    float64
# NUM_BATH         object
# SQ_M             object
# dtype: object

# %%
df.columns
# Out:
# Index(['PID', 'ST_NUM', 'ST_NAME', 'OWN_OCCUPIED', 'NUM_BEDROOMS', 'NUM_BATH',
#        'SQ_M'],
#       dtype='object')

# %%
df
# Out:
#       PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_M
# 0     กอบ   104.0   PUTNAM            Y           3.0        1   1000
# 1     แนน   197.0    LETON            n           3.0        1     --
# 2     Lam     NaN    LETON            N           NaN        1    850
# 3   Ninan   201.0    BEREY            N           1.0       -2  700.5
# 4     Nii     NaN    BEREY            Y           2.0     2ABC   1600
# 5     Tom   207.0    BEREY            Y           3.0      1.5  800.8
# 6   Green     NaN   WAGTON          NaN           2.0        3    950
# 7   Shasa   213.0  TREMONT            Y           1.0        1    NaN
# 8   Alisa   215.0  TREMONT            Y           2.0        2   1800
# 9     Ksb   216.0  TREMONT            n           2.0        2   90.5
# 10    Jib   217.0  TREMONT           12           2.0        2   70.2

# %%
df.drop(['ST_NUM','ST_NAME'],axis = 1, inplace=True)

# %%
df
# Out:
#       PID OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_M
# 0     กอบ            Y           3.0        1   1000
# 1     แนน            n           3.0        1     --
# 2     Lam            N           NaN        1    850
# 3   Ninan            N           1.0       -2  700.5
# 4     Nii            Y           2.0     2ABC   1600
# 5     Tom            Y           3.0      1.5  800.8
# 6   Green          NaN           2.0        3    950
# 7   Shasa            Y           1.0        1    NaN
# 8   Alisa            Y           2.0        2   1800
# 9     Ksb            n           2.0        2   90.5
# 10    Jib           12           2.0        2   70.2

# %%
df.rename(columns={"PID":'id','OWN_OCCUPIED':'own','NUM_BEDROOMS':'bedroom','NUM_BATH':'bathroom',"SQ_M":'area'},inplace=True)
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    n      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    n      2.0        2   90.5
# 10    Jib   12      2.0        2   70.2

# %%
df.own.value_counts()
# Out:
# Y     5
# n     2
# N     2
# 12    1
# Name: own, dtype: int64

# %%
import seaborn as sns
sns.countplot('own',data=df)

# %%
cols_to_check = ['own','bathroom','area']
for colm in cols_to_check:
    print(colm)
    colm_val = df[colm].unique()
    for item in colm_val:
        print(item)
    print('=======')
# Out:
# own
# Y
# n
# N
# nan
# 12
# ...
# bathroom
# 1
# -2
# 2ABC
# 1.5
# 3
# 2
# ...
# area
# 1000
# --
# 850
# 700.5
# 1600
# 800.8
# 950
# nan
# 1800
# 90.5
# 70.2
# ...

# %%
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    n      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    n      2.0        2   90.5
# 10    Jib   12      2.0        2   70.2

# %%
df.own = df.own.str.upper()
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    N      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    N      2.0        2   90.5
# 10    Jib   12      2.0        2   70.2

# %%
df.own.value_counts()
# Out:
# Y     5
# N     4
# 12    1
# Name: own, dtype: int64

# %% [markdown]
# # แก้ไข columns bedroom

# %%
df.bedroom = pd.to_numeric(df['bedroom'],downcast='signed')

# %%
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    N      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    N      2.0        2   90.5
# 10    Jib   12      2.0        2   70.2

# %% [markdown]
# # ต้องการตรวจสอบหลายคอลลัม

# %%
for col in df.columns:
    itemIncol = df[col].value_counts()
    print(itemIncol)
    print('======================')
# Out:
# แนน      1
# Ninan    1
# Green    1
# Jib      1
# Nii      1
# Tom      1
# Lam      1
# Shasa    1
# กอบ      1
# Ksb      1
# Alisa    1
# Name: id, dtype: int64
# ...
# Y     5
# N     4
# 12    1
# Name: own, dtype: int64
# ...
# 2.0    5
# 3.0    3
# 1.0    2
# Name: bedroom, dtype: int64
# ...
# 1       4
# 2       3
# -2      1
# 1.5     1
# 2ABC    1
# 3       1
# Name: bathroom, dtype: int64
# ...
# 1000     1
# 70.2     1
# 950      1
# 1800     1
# --       1
# 1600     1
# 800.8    1
# 90.5     1
# 850      1
# 700.5    1
# Name: area, dtype: int64
# ...

# %% [markdown]
# # Workshop 5 จัดการกับข้อมูลผิดชนิด

# %%
df.own = df.own.astype('category')

# %%
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    N      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    N      2.0        2   90.5
# 10    Jib   12      2.0        2   70.2

# %%
df.at[10,'own'] = 'Y'
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    N      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    N      2.0        2   90.5
# 10    Jib    Y      2.0        2   70.2

# %%
df
# Out:
#        id  own  bedroom bathroom   area
# 0     กอบ    Y      3.0        1   1000
# 1     แนน    N      3.0        1     --
# 2     Lam    N      NaN        1    850
# 3   Ninan    N      1.0       -2  700.5
# 4     Nii    Y      2.0     2ABC   1600
# 5     Tom    Y      3.0      1.5  800.8
# 6   Green  NaN      2.0        3    950
# 7   Shasa    Y      1.0        1    NaN
# 8   Alisa    Y      2.0        2   1800
# 9     Ksb    N      2.0        2   90.5
# 10    Jib    Y      2.0        2   70.2

# %%
df = pd.read_csv('data_clean_bfclean.csv')

# %%
df.drop(['PID','ST_NUM'],inplace=True,axis=1)

# %%
df['OWN_OCCUPIED'].replace('12',np.nan,inplace=True)

# %%
df = pd.read_csv('data_clean_bfclean.csv')
df
# Out:
#       PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_M
# 0     กอบ   104.0   PUTNAM            Y           3.0        1   1000
# 1     แนน   197.0    LETON            n           3.0        1     --
# 2     Lam     NaN    LETON            N           NaN        1    850
# 3   Ninan   201.0    BEREY            N           1.0       -2  700.5
# 4     Nii     NaN    BEREY            Y           2.0     2ABC   1600
# 5     Tom   207.0    BEREY            Y           3.0      1.5  800.8
# 6   Green     NaN   WAGTON          NaN           2.0        3    950
# 7   Shasa   213.0  TREMONT            Y           1.0        1    NaN
# 8   Alisa   215.0  TREMONT            Y           2.0        2   1800
# 9     Ksb   216.0  TREMONT            n           2.0        2   90.5
# 10    Jib   217.0  TREMONT           12           2.0        2   70.2

# %%
df.drop(df[df.OWN_OCCUPIED == '12'].index)
# Out:
#      PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_M
# 0    กอบ   104.0   PUTNAM            Y           3.0        1   1000
# 1    แนน   197.0    LETON            n           3.0        1     --
# 2    Lam     NaN    LETON            N           NaN        1    850
# 3  Ninan   201.0    BEREY            N           1.0       -2  700.5
# 4    Nii     NaN    BEREY            Y           2.0     2ABC   1600
# 5    Tom   207.0    BEREY            Y           3.0      1.5  800.8
# 6  Green     NaN   WAGTON          NaN           2.0        3    950
# 7  Shasa   213.0  TREMONT            Y           1.0        1    NaN
# 8  Alisa   215.0  TREMONT            Y           2.0        2   1800
# 9    Ksb   216.0  TREMONT            n           2.0        2   90.5

# %%
df['SQ_M'] = pd.to_numeric(df['SQ_M'], errors='coerce',downcast='float')
df
# Out:
#       PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH         SQ_M
# 0     กอบ   104.0   PUTNAM            Y           3.0        1  1000.000000
# 1     แนน   197.0    LETON            n           3.0        1          NaN
# 2     Lam     NaN    LETON            N           NaN        1   850.000000
# 3   Ninan   201.0    BEREY            N           1.0       -2   700.500000
# 4     Nii     NaN    BEREY            Y           2.0     2ABC  1600.000000
# 5     Tom   207.0    BEREY            Y           3.0      1.5   800.799988
# 6   Green     NaN   WAGTON          NaN           2.0        3   950.000000
# 7   Shasa   213.0  TREMONT            Y           1.0        1          NaN
# 8   Alisa   215.0  TREMONT            Y           2.0        2  1800.000000
# 9     Ksb   216.0  TREMONT            n           2.0        2    90.500000
# 10    Jib   217.0  TREMONT           12           2.0        2    70.199997

# %%
df['NUM_BATH'] = pd.to_numeric(df['NUM_BATH'],errors='coerce',downcast='integer')
df['NUM_BATH'] = df['NUM_BATH'].apply(lambda x: x if x % 1==0 else np.nan )
df['NUM_BATH'] = df['NUM_BATH'].apply(lambda x: x if x > 0 else np.nan)

# %%
df = pd.read_csv('data_clean6_after_clean_bedroom_dup.csv')
df
# Out:
#       id  own  bedroom  bathroom    area
# 0    กอบ    Y        3         1  1000.0
# 1    แนน    N        3         1     NaN
# 2  Green  NaN        2         3   950.0
# 3  Shasa    Y        1         1     NaN
# 4  Alisa    Y        2         2  1800.0
# 5  Alisa    Y        2         2  1200.0
# 6    Ksb    N        2         2    90.5
# 7    Ksb    N        2         2    90.5
# 8    Jib  NaN        2         2    70.2

# %%
df[df.duplicated()]
# Out:
#     id own  bedroom  bathroom  area
# 7  Ksb   N        2         2  90.5

# %%
df[df.duplicated('id')]
# Out:
#       id own  bedroom  bathroom    area
# 5  Alisa   Y        2         2  1200.0
# 7    Ksb   N        2         2    90.5

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset='id')
# Out:
#       id  own  bedroom  bathroom    area
# 0    กอบ    Y        3         1  1000.0
# 1    แนน    N        3         1     NaN
# 2  Green  NaN        2         3   950.0
# 3  Shasa    Y        1         1     NaN
# 4  Alisa    Y        2         2  1800.0
# 6    Ksb    N        2         2    90.5
# 8    Jib  NaN        2         2    70.2

# %%
df
# Out:
#       id  own  bedroom  bathroom    area
# 0    กอบ    Y        3         1  1000.0
# 1    แนน    N        3         1     NaN
# 2  Green  NaN        2         3   950.0
# 3  Shasa    Y        1         1     NaN
# 4  Alisa    Y        2         2  1800.0
# 5  Alisa    Y        2         2  1200.0
# 6    Ksb    N        2         2    90.5
# 7    Ksb    N        2         2    90.5
# 8    Jib  NaN        2         2    70.2

# %%
df.isnull().sum()
# Out:
# id          0
# own         2
# bedroom     0
# bathroom    0
# area        2
# dtype: int64
